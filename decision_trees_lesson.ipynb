# %% [markdown]
# # Decision Tree Lesson

# %%
# General DS Imports
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# Decision Tree and Model Evaluation Imports
from sklearn.tree import DecisionTreeClassifier, plot_tree, export_text
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, plot_confusion_matrix

# %% [markdown]
# ### Question: Can we predict whether someone is a smoker based on the tips data?

# %%
np.random.seed(25)
tips = sns.load_dataset('tips')

# %%
tips.sample(5)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 40        16.04  2.24    Male     No   Sat  Dinner     3
# 19        20.65  3.35    Male     No   Sat  Dinner     3
# 73        25.28  5.00  Female    Yes   Sat  Dinner     2
# 142       41.19  5.00    Male     No  Thur   Lunch     5
# 213       13.27  2.50  Female    Yes   Sat  Dinner     2

# %%
tips.columns.values
# Out:
# array(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'],
#       dtype=object)

# %%
tips = pd.get_dummies(tips, columns=['sex', 'day', 'time'], drop_first=True)
tips.head()
# Out:
#    total_bill   tip smoker  size  sex_Female  day_Fri  day_Sat  day_Sun  \
# 0       16.99  1.01     No     2           1        0        0        1
# 1       10.34  1.66     No     3           0        0        0        1
# 2       21.01  3.50     No     3           0        0        0        1
# 3       23.68  3.31     No     2           0        0        0        1
# 4       24.59  3.61     No     4           1        0        0        1
#
#    time_Dinner
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1

# %%
# splitting dataset into X and y components before doing the train/validate/test split
X = tips[['total_bill', 'tip', 'size']] #features, inputs
y = tips.smoker  #target, answers

X_train_and_validate,X_test, y_train_and_validate, y_test = train_test_split(X, y, random_state=123, test_size=.3)
X_train, X_validate, y_train, y_validate = train_test_split(X_train_and_validate, y_train_and_validate, random_state=123, test_size=.2)

# %%
X_train.head()
# Out:
#      total_bill   tip  size
# 113       23.95  2.55     2
# 100       11.35  2.50     2
# 13        18.43  3.00     4
# 152       17.26  2.74     3
# 94        22.75  3.25     2

# %%
y_train[:5]
# Out:
# 113     No
# 100    Yes
# 13      No
# 152     No
# 94      No
# Name: smoker, dtype: category
# Categories (2, object): ['Yes', 'No']

# %%
# the majority of this sample the target: smoker are non smokers:
y_train.value_counts()
# Out:
# No     83
# Yes    53
# Name: smoker, dtype: int64

# %% [markdown]
# ## Decision Tree Modeling
#
# #### Step 1: Create Your Recipe

# %%
# Create the decision tree object and specify hyperparams
tree = DecisionTreeClassifier(max_depth = 3)

# %%
# When created this is an alogorithm, use set of instructions, algorithm 1
# once it is fitted it becomes a model, model 1
tree
# Out:
# DecisionTreeClassifier(max_depth=3)

# %% [markdown]
# #### Step 2: Fit your model to your in-sample data (train)
#
# Until a model learns from your data, its just an algorithm. After it has learned and changed its algorithmic structure (i.e. has decided which questions to ask and in what order), then it can be called a model.

# %%
# can use .fit for the x component or y component, this will be fully flushed out. before its not
# the data it needs to learn from
# once we do tree. fit it will become a model and will be that model for the rest of it.Model1
# once fitted it is a static decision tree
tree.fit(X_train, y_train)

# Rudimentary visualization of model structure
print(export_text(tree, feature_names=X_train.columns.tolist()))
# Out:
# |--- total_bill <= 32.65
# |   |--- tip <= 1.00
# |   |   |--- class: Yes
# |   |--- tip >  1.00
# |   |   |--- total_bill <= 28.36
# |   |   |   |--- class: No
# |   |   |--- total_bill >  28.36
# |   |   |   |--- class: No
# |--- total_bill >  32.65
# |   |--- total_bill <= 46.23
# |   |   |--- class: Yes
# |   |--- total_bill >  46.23
# |   |   |--- class: No

# %%
# Visualize the tree
plt.figure(figsize=(12, 7))
plot_tree(tree, feature_names=X_train.columns, class_names=y_train.unique())
plt.show()

# %% [markdown]
# #### Step 3: Use your model to make predictions on the in-sample data

# %%
# .predict to be used against actual data y_train
tree.predict(X_train)
# Out:
# array(['No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'Yes', 'No', 'No', 'Yes', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No',
#        'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'Yes', 'No'], dtype=object)

# %%
# save predict x_train data and y_train data(actual)
predictions = tree.predict(X_train)
actual = y_train

# %% [markdown]
# #### Step 4: Evaluate your predictions

# %%
confusion_matrix(actual, predictions)
# Out:
# array([[83,  0],
#        [44,  9]])

# %%
pd.crosstab(actual, predictions)
# Out:
# col_0   No  Yes
# smoker
# Yes     44    9
# No      83    0

# %%
plot_confusion_matrix(tree, X_train, y_train, display_labels=['Non-Smoker', 'Smoker'])
# Out:
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
# support column is the overall columns of no's
print(classification_report(actual, predictions))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.65      1.00      0.79        83
#          Yes       1.00      0.17      0.29        53
#
#     accuracy                           0.68       136
#    macro avg       0.83      0.58      0.54       136
# weighted avg       0.79      0.68      0.60       136

# %% [markdown]
# #### Step 5: Use best n models on out-of-sample data (validate)
#
# In this case, I only have one model

# %%
# . predict and use validate data should only some of your models
predictions = tree.predict(X_validate)
actual = y_validate

print(classification_report(actual, predictions))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.69      0.91      0.78        22
#          Yes       0.60      0.25      0.35        12
#
#     accuracy                           0.68        34
#    macro avg       0.64      0.58      0.57        34
# weighted avg       0.66      0.68      0.63        34

# %%
# your model will never change, it was built and the model does not change,
# even if we feed it new inputs and values, 1)tree was initiated, 2)fit and not refitted.
# it was train once and will only be train once
# Visualize the tree
plt.figure(figsize=(12, 7))
plot_tree(tree, feature_names=X_validate.columns, class_names=y_validate.unique())
plt.show()

# %% [markdown]
# #### Step 6: Use single best model to make predictions from out-of-sample data (test)

# %%
predictions = tree.predict(X_test)
actual = y_test

print(classification_report(actual, predictions))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.61      0.85      0.71        46
#          Yes       0.30      0.11      0.16        28
#
#     accuracy                           0.57        74
#    macro avg       0.45      0.48      0.43        74
# weighted avg       0.49      0.57      0.50        74

# %% [markdown]
# #### Bonus: What happens if we change some of the hyperparameters?
#
# Let's try changing max depth to none. This model will ask questions until every leaf gini is as small as absolutely possible:

# %%
# Create the decision tree object and specify hyperparams
tree = DecisionTreeClassifier(max_depth=None) 
tree.fit(X_train, y_train)

print(export_text(tree, feature_names=X_train.columns.tolist()))
# Out:
# |--- total_bill <= 32.65
# |   |--- tip <= 1.00
# |   |   |--- class: Yes
# |   |--- tip >  1.00
# |   |   |--- total_bill <= 28.36
# |   |   |   |--- total_bill <= 26.50
# |   |   |   |   |--- tip <= 3.96
# |   |   |   |   |   |--- size <= 2.50
# |   |   |   |   |   |   |--- tip <= 1.49
# |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |--- tip >  1.49
# |   |   |   |   |   |   |   |--- tip <= 3.49
# |   |   |   |   |   |   |   |   |--- tip <= 3.39
# |   |   |   |   |   |   |   |   |   |--- tip <= 3.23
# |   |   |   |   |   |   |   |   |   |   |--- tip <= 3.05
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 17
# |   |   |   |   |   |   |   |   |   |   |--- tip >  3.05
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |   |--- tip >  3.23
# |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |--- tip >  3.39
# |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |--- tip >  3.49
# |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |--- size >  2.50
# |   |   |   |   |   |   |--- tip <= 3.75
# |   |   |   |   |   |   |   |--- tip <= 3.36
# |   |   |   |   |   |   |   |   |--- tip <= 3.12
# |   |   |   |   |   |   |   |   |   |--- total_bill <= 23.41
# |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |--- total_bill >  23.41
# |   |   |   |   |   |   |   |   |   |   |--- total_bill <= 24.05
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |   |   |--- total_bill >  24.05
# |   |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |--- tip >  3.12
# |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |--- tip >  3.36
# |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |--- tip >  3.75
# |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |--- tip >  3.96
# |   |   |   |   |   |--- total_bill <= 17.55
# |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |--- total_bill >  17.55
# |   |   |   |   |   |   |--- size <= 2.50
# |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |--- size >  2.50
# |   |   |   |   |   |   |   |--- size <= 4.50
# |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |--- size >  4.50
# |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |--- total_bill >  26.50
# |   |   |   |   |--- size <= 3.50
# |   |   |   |   |   |--- class: Yes
# |   |   |   |   |--- size >  3.50
# |   |   |   |   |   |--- size <= 4.50
# |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |--- size >  4.50
# |   |   |   |   |   |   |--- class: Yes
# |   |   |--- total_bill >  28.36
# |   |   |   |--- class: No
# |--- total_bill >  32.65
# |   |--- total_bill <= 46.23
# |   |   |--- class: Yes
# |   |--- total_bill >  46.23
# |   |   |--- class: No

# %%
plt.figure(figsize=(16, 9), dpi=300)
plot_tree(tree, feature_names=X_train.columns, class_names=y_train.unique())
plt.show()

# %% [markdown]
# #### How accurate is our crazy model on our training data?

# %%
# . score is an accuracy
tree.score(X_train, y_train) # 100%!
# Out:
# 1.0

# %% [markdown]
# #### How accurate is our crazy model on out-of-sample data?

# %%
# large variation between sample performance and actual performance
tree.score(X_validate, y_validate)
# Out:
# 0.5882352941176471

# %%
y_validate.value_counts(normalize=True)
# Out:
# No     0.647059
# Yes    0.352941
# Name: smoker, dtype: float64

# %% [markdown]
# We would have had better accuracy just guessing "No" on everything

# %%
# The mode is a great baseline
baseline = y_train.mode()

# %%
baseline
# Out:
# 0    No
# Name: smoker, dtype: category
# Categories (2, object): ['Yes', 'No']

# %%
# baselinemodel, guess everyone is not a smoker
X_train['baseline_prediction']= 'No'

# %%
actual = y_train
predictions = X_train.baseline_prediction

# %%
actual
# Out:
# 113     No
# 100    Yes
# 13      No
# 152     No
# 94      No
#       ...
# 8       No
# 14      No
# 38      No
# 92     Yes
# 138    Yes
# Name: smoker, Length: 136, dtype: category
# Categories (2, object): ['Yes', 'No']

# %%
predictions
# Out:
# 113    No
# 100    No
# 13     No
# 152    No
# 94     No
#        ..
# 8      No
# 14     No
# 38     No
# 92     No
# 138    No
# Name: baseline_prediction, Length: 136, dtype: object

# %%
pd.crosstab(actual, predictions)
# Out:
# baseline_prediction  No
# smoker
# Yes                  53
# No                   83

# %%
# accuracy
83/(83+53)
# Out:
# 0.6102941176470589

# %% [markdown]
# ## What did we miss? What can we do next?
#
# - Making a baseline model and properly evaluating it
# - Make more models, try out different combinations of independent variables and hyperparameters
# > **Note**: Our X can change, but our y remains constant
# - Quantify and compare those models (on validate!) against each other and the baseline
#
# ## Pruning
# Decision Trees have a high risk of being overfit to our training data. We can use `max_depth` and `min_samples` as a way to reduce overfitting. We could build a process that exhaustively checked every hyperparameter combination or we can use an existing process:
# - Look into [`cost_complexity_pruning_path`](https://scikit-learn.org/stable/auto_examples/tree/plot_cost_complexity_pruning.html)
#
# # Exercises
#
# Using the titanic data, in your classification-exercises repository, create a notebook, `model.ipynb` where you will do the following:
#
# 1. What is your baseline prediction? What is your baseline accuracy? remember: your baseline prediction for a classification problem is predicting the most prevelant class in the training dataset (the mode). When you make those predictions, what is your accuracy? This is your baseline accuracy.
#
# 2. Fit the decision tree classifier to your training sample and transform (i.e. make predictions on the training sample)
#
# 3. Evaluate your in-sample results using the model score, confusion matrix, and classification report.
#
# 4. Compute: Accuracy, true positive rate, false positive rate, true negative rate, false negative rate, precision, recall, f1-score, and support.
#
# 5. Run through steps 2-4 using a different max_depth value.
#
# 6. Which model performs better on your in-sample data?
#
# 7. Which model performs best on your out-of-sample data, the validate set?
#
# 8. Work through these same exercises using the Telco dataset.
